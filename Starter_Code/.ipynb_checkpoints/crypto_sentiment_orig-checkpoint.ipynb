# %%
import os
import pandas as pd
# %matplotlib inline

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Download/Update the VADER Lexicon
nltk.download('vader_lexicon')

# Initialize the VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\vinay\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# # News Headlines Sentiment
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Read your api key environment variable
api_key = "ff8d15d7f81449299b5be7212419f013"

# %%
# Create a newsapi client
from newsapi import NewsApiClient
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
bc_headlines = newsapi.get_everything(q="bitcoin", language="en")
bc_headlines["articles"][0]
# Out:
# {'source': {'id': 'engadget', 'name': 'Engadget'},
#  'author': 'Igor Bonifacic',
#  'title': "HTC's Exodus 1s can run a full Bitcoin node for under $250",
#  'description': 'After first teasing the device earlier this year, HTC has detailed its new, more affordable Exodus 1s blockchain smartphone. The highlight feature of the device is that it can function as a full node. This means the phone is able to validate and transmit Bitc…',
#  'url': 'https://www.engadget.com/2019/10/19/htcs-exodus-1s-can-run-a-full-bitcoin-node-for-under-250/',
# ...

# %%
# Fetch the Ethereum news articles
et_headlines = newsapi.get_everything(q="ethereum", language="en")
et_headlines["articles"][0]
# Out:
# {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#  'author': 'David Canellis',
#  'title': 'IKEA just allowed an invoice to be paid via the Ethereum blockchain',
#  'description': 'IKEA Iceland has used Ethereum technology to settle an invoice with a local retailer, accepting payment in blockchainified digital cash. Supply chain payments firm Tradeshift facilitated the transfer using an Ethereum-based version of the Icelandic króna crea…',
#  'url': 'https://thenextweb.com/hardfork/2019/10/02/ikea-iceland-smart-contracts-ethereum-tradeshift-monerium-invoice-nordic-store/',
#  'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F10%2Fikea.jpg&signature=a0e7268a6116bde5ff687adb1195cf03',
#  'publishedAt': '2019-10-02T13:33:44Z',
# ...

# %%
# Create the Bitcoin sentiment scores DataFrame
bc_sentiments = []

for article in bc_headlines["articles"]:
    try:
        sentiment = analyzer.polarity_scores(article["content"])
      
        bc_sentiments.append({
            "text": article["content"],
            "date": article["publishedAt"][:10],
            "compound": sentiment["compound"],
            "positive": sentiment["pos"],
            "negative": sentiment["neg"],
            "neutral": sentiment["neu"]
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
bc_df = pd.DataFrame(bc_sentiments)


# Drop Date 
bc_df.drop("date", axis=1, inplace=True)

# Reorder DataFrame columns
cols = ["compound", "negative", "neutral", "positive", "text",]
bc_df = bc_df[cols]
bc_df.head()
# Out:
#    compound  negative  neutral  positive  \
# 0    0.2263     0.000    0.960     0.040
# 1   -0.6486     0.139    0.817     0.044
# 2   -0.7845     0.154    0.846     0.000
# 3   -0.4767     0.069    0.931     0.000
# 4    0.0258     0.080    0.859     0.061
#
#                                                 text
# 0  At least that's the idea. While it's not as in...
# 1  Since its inception in 2009, Bitcoin has made ...
# 2  New allegations against a bitcoin developer sp...
# 3  Say it with me: Bitcoin is not anonymous. \r\n...
# 4  Federal authorities in the U.S. have unsealed ...

# %%
# Create the ethereum sentiment scores DataFrame
et_sentiments = []

for article in et_headlines["articles"]:
    try:
        sentiment = analyzer.polarity_scores(article["content"])
      
        et_sentiments.append({
            "compound": sentiment["compound"],
            "negative": sentiment["neg"],
            "neutral": sentiment["neu"],
            "positive": sentiment["pos"],
            "text": article["content"]
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
et_df = pd.DataFrame(et_sentiments)
et_df.head()
# Out:
#    compound  negative  neutral  positive  \
# 0    0.3818       0.0    0.933     0.067
# 1    0.1901       0.0    0.956     0.044
# 2    0.2263       0.0    0.960     0.040
# 3    0.4019       0.0    0.932     0.068
# 4    0.6879       0.0    0.886     0.114
#
#                                                 text
# 0  IKEA Iceland has used Ethereum ETHtechnology t...
# 1  Blockchains like Ethereums are often pitched a...
# 2  At least that's the idea. While it's not as in...
# 3  TLDR: The Complete Blockchain and Ethereum Pro...
# 4  Our robot colleague Satoshi Nakaboto writes ab...

# %%
# Describe the Bitcoin Sentiment
bc_df.describe()
# Out:
#         compound   negative    neutral   positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.294505   0.030350   0.899050   0.070550
# std     0.452100   0.049367   0.052054   0.042462
# min    -0.784500   0.000000   0.756000   0.000000
# 25%     0.176175   0.000000   0.877000   0.064000
# 50%     0.507000   0.000000   0.931000   0.068000
# 75%     0.507000   0.048750   0.932000   0.070250
# max     0.806700   0.154000   0.960000   0.206000

# %%
# Describe the Ethereum Sentiment
et_df.describe()
# Out:
#         compound  negative    neutral   positive
# count  20.000000  20.00000  20.000000  20.000000
# mean    0.088625   0.04545   0.888900   0.065600
# std     0.382948   0.06220   0.080719   0.039403
# min    -0.823200   0.00000   0.726000   0.000000
# 25%     0.000000   0.00000   0.844750   0.040750
# 50%     0.165500   0.03150   0.898500   0.061000
# 75%     0.307000   0.05650   0.944750   0.087500
# max     0.687900   0.21000   1.000000   0.139000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: bitcoin
#
# Q: Which coin had the highest compound score?
#
# A: bitcoin
#
# Q. Which coin had the highest positive score?
#
# A: bitcoin

# %% [markdown]
# ---

# %% [markdown]
# # Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Expand the default stop words list if necessary
nltk.download("stopwords")
sw = set(stopwords.words('english'))
sw_addon = {'said', 'mln', 'kl', 'say'}
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vinay\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Create a list of the words
    words = word_tokenize(text)
    # Convert the words to lowercase
    words_lower = [word.lower() for word in words]
    # Remove the punctuation
    regex = re.compile("[^a-zA-Z0-9 ]")
    words_lower_no_punc = [regex.sub('', word) for word in words_lower]
    # Remove the stop words
    words_lower_no_punc_no_sw = [word for word in words_lower_no_punc if word not in sw.union(sw_addon)]
    # Lemmatize Words into root words
    tokens = [lemmatizer.lemmatize(word) for word in words_lower_no_punc_no_sw]
    return tokens

# %%
# Create a new tokens column for bitcoin
lemmatizer = WordNetLemmatizer()
bc_df["tokens"] = bc_df["text"].apply(tokenizer)
bc_df.head()
# Out:
#    compound  negative  neutral  positive  \
# 0    0.2263     0.000    0.960     0.040
# 1   -0.6486     0.139    0.817     0.044
# 2   -0.7845     0.154    0.846     0.000
# 3   -0.4767     0.069    0.931     0.000
# 4    0.0258     0.080    0.859     0.061
#
#                                                 text  \
# 0  At least that's the idea. While it's not as in...
# 1  Since its inception in 2009, Bitcoin has made ...
# 2  New allegations against a bitcoin developer sp...
# 3  Say it with me: Bitcoin is not anonymous. \r\n...
# 4  Federal authorities in the U.S. have unsealed ...
#
#                                               tokens
# 0  [least, idea, , intensive, mining, bitcoin, , ...
# 1  [since, inception, 2009, , bitcoin, made, ruin...
# 2  [new, allegation, bitcoin, developer, spurred,...
# 3  [, bitcoin, anonymous, , three, hundred, thirt...
# 4  [federal, authority, u, unsealed, charge, sout...

# %%
# Create a new tokens column for ethereum
et_df["tokens"] = et_df["text"].apply(tokenizer)
et_df.head()
# Out:
#    compound  negative  neutral  positive  \
# 0    0.3818       0.0    0.933     0.067
# 1    0.1901       0.0    0.956     0.044
# 2    0.2263       0.0    0.960     0.040
# 3    0.4019       0.0    0.932     0.068
# 4    0.6879       0.0    0.886     0.114
#
#                                                 text  \
# 0  IKEA Iceland has used Ethereum ETHtechnology t...
# 1  Blockchains like Ethereums are often pitched a...
# 2  At least that's the idea. While it's not as in...
# 3  TLDR: The Complete Blockchain and Ethereum Pro...
# 4  Our robot colleague Satoshi Nakaboto writes ab...
#
#                                               tokens
# 0  [ikea, iceland, used, ethereum, ethtechnology,...
# 1  [blockchains, like, ethereums, often, pitched,...
# 2  [least, idea, , intensive, mining, bitcoin, , ...
# 3  [tldr, , complete, blockchain, ethereum, progr...
# 4  [robot, colleague, satoshi, nakaboto, writes, ...

# %% [markdown]
# ---

# %% [markdown]
# # NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams
import numpy as np

# %%
# Generate the Bitcoin N-grams where N=2
def process_text(doc):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', doc)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in lem if word.lower() not in sw]
    return output

# %%
# Combine all articles
bc_corpus = [article["content"] for article in bc_headlines["articles"]]
bc_big_string = ' '.join(bc_corpus)
bc_processed = process_text(bc_big_string)
bc_bigrams = ngrams(bc_processed, n=2)
Counter(bc_bigrams).most_common(10)
# Out:
# array({('satoshi', 'nakaboto'): 26, ('robot', 'colleague'): 13, ('colleague', 'satoshi'): 13, ('nakaboto', 'writes'): 13, ('writes', 'bitcoin'): 13, ('bitcoin', 'btc'): 13, ('btc', 'every'): 13, ('every', 'fucking'): 13, ('fucking', 'daywelcome'): 13, ('daywelcome', 'another'): 13},
#       dtype=object)

# %%
# Generate the Ethereum N-grams where N=2
et_corpus = [article["content"] for article in et_headlines["articles"]]
et_big_string = ' '.join(et_corpus)
et_processed = process_text(et_big_string)
et_bigrams = ngrams(et_processed, n=2)
Counter(et_bigrams).most_common(10)
# Out:
# array({('bitcoin', 'btc'): 4, ('uk', 'police'): 3, ('satoshi', 'nakaboto'): 2, ('perth', 'mint'): 2, ('ethereum', 'eth'): 2, ('ripple', 'xrp'): 2, ('security', 'law'): 2, ('char', 'uk'): 2, ('criminallyseized', 'bitcoin'): 2, ('ikea', 'iceland'): 1},
#       dtype=object)

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Get the top 10 words for Bitcoin
token_count(bc_processed)
# Out:
# [('bitcoin', 44),
#  ('satoshi', 27),
#  ('nakaboto', 26),
#  ('char', 19),
#  ('say', 14),
#  ('robot', 13),
#  ('colleague', 13),
#  ('writes', 13),
#  ('btc', 13),
#  ('every', 13)]

# %%
# Get the top 10 words for Ethereum
token_count(et_processed)
# Out:
# [('char', 20),
#  ('bitcoin', 8),
#  ('ethereum', 6),
#  ('ha', 5),
#  ('blockchain', 5),
#  ('today', 5),
#  ('cryptocurrency', 5),
#  ('security', 5),
#  ('btc', 4),
#  ('auction', 4)]

# %% [markdown]
# # Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
wc = WordCloud().generate(' '.join(bc_processed))
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud
wc = WordCloud().generate(' '.join(et_processed))
plt.imshow(wc)

# %% [markdown]
# # Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both coins and visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Optional - download a language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Bitcoin NER

# %%
# Concatenate all of the bitcoin text together
bc_ner = ' '.join(bc_corpus)
bc_ner
# Out:
# "At least that's the idea. While it's not as intensive as mining Bitcoin, running a full node still requires a lot of computing power. In fact, HTC recommends only using the feature while the phone is connected to WiFi and plugged into its power adapter. The c… [+2014 chars] Since its inception in 2009, Bitcoin has made and ruined fortunes, helped sell fentanyl and books about cryptocurrency, withstood literally millions of jokes and just as many predictions of imminent collapse, andthrough a process opaque to most people, myself… [+10529 chars] New allegations against a bitcoin developer spurred a deposition from Jacob Appelbaum\r\nPhoto by Ingo Wagner / Getty Images\r\nIn the summer of 2016, a flood of abuse allegations came out against celebrity Tor developer Jacob Appelbaum, a shocking blow to one of… [+6852 chars] Say it with me: Bitcoin is not anonymous.\xa0\r\nThree hundred and thirty-seven alleged members of a massive dark web child pornography website were reminded of that f
# ...

# %%
# Run the NER processor on all of the text
bc_ner_processed = nlp(bc_ner)
# Add a title to the document
bc_ner_processed.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(bc_ner_processed, style='ent')
# Out:
# <h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">At least that's the idea. While it's not as intensive as mining
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , running a full node still requires a lot of computing power. In fact,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     HTC
# ...

# %%
# List all Entities
bc_entities = [ent.text for ent in bc_ner_processed.ents]

for i in bc_entities:
    print(i)
# Out:
# Bitcoin
# HTC
# 2009
# Bitcoin
# millions
# +10529
# Jacob Appelbaum
# Ingo Wagner / Getty Images
# the summer of 2016
# Tor
# Jacob Appelbaum
# Bitcoin
# Three hundred and thirty-seven
# last year
# U.S.
# South Korean
# Welcome
# Video
# Bitcoin
# Facebook
# US
# Libra
# China
# American
# Satoshi Nakaboto
# Bitcoin BTC
# Bitcoin
# Today
# Satoshi Nakaboto
# Bitcoin
# the past 24 hours
# Aristotle
# The Fine Print
# Satoshi Nakaboto
# Bitcoin BTC
# Bitcoin
# Today
# Satoshi Nakaboto
# Bitcoin
# the past 24 hours
# Rousseau
# Satoshi Nakaboto
# Bitcoin BTC
# Bitcoin
# Today
# Satoshi Nakaboto
# Bitcoin
# the past 24 hours
# Bentham
# Yolo
# Bitcoin
# Satoshi Nakaboto
# Bitcoin BTC
# Bitcoin
# Today
# Satoshi Nakaboto
# Bitcoin
# the past 24 hours
# Nightingale
# Satoshi Nakaboto
# Bitcoin BTC
# Bitcoin
# Today
# Satoshi Nakaboto
# Bitcoin
# the past 24 hours
# Baudriallard
# +2981
# Satoshi Nakaboto
# Bitcoin BTC
# Bitcoin
# Today
# Satoshi Nakaboto
# Bitcoin
# the past 24 hours
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Ethereum NER

# %%
# Concatenate all of the bitcoin text together
et_ner = ' '.join(et_corpus)
et_ner
# Out:
# 'IKEA Iceland has used Ethereum ETHtechnology to settle an invoice with a local retailer, accepting payment\xa0in blockchainified\xa0digital cash.\r\nSupply chain payments firm Tradeshift facilitated the transfer using an Ethereum-based version of the Icelandic\xa0króna … [+1062 chars] Blockchains like Ethereums are often pitched as self-sovereign money networks that operate independently of states, financial institutions, and corporations\xa0 but recent research shows this might not be reality.\r\nAs it turns out, its really centralized cloud s… [+3927 chars] At least that\'s the idea. While it\'s not as intensive as mining Bitcoin, running a full node still requires a lot of computing power. In fact, HTC recommends only using the feature while the phone is connected to WiFi and plugged into its power adapter. The c… [+2014 chars] TLDR: The Complete Blockchain and Ethereum Programming Bundle help you understand cryptocurrencies and its root technology for under $30.\r\nEverybodys go
# ...

# %%
# Run the NER processor on all of the text
et_ner_processed = nlp(et_ner)
# Add a title to the document
et_ner_processed.user_data["title"] = "Ethereun NER"

displacy.render(et_ner_processed, style='ent')
# Out:
# <h2 style="margin: 0">Ethereun NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">IKEA
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Iceland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has used
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Ethereum ETHtechnology
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Supply chain payments firm
# ...

# %%
# List all Entities
et_entities = [ent.text for ent in et_ner_processed.ents]

for i in et_entities:
    print(i)
# Out:
# Iceland
# Ethereum ETHtechnology
# Tradeshift
# Ethereum
# Icelandic
# Bitcoin
# HTC
# The Complete Blockchain and Ethereum Programming Bundle
# 30
# Everybodys
# Satoshi Nakaboto
# Bitcoin BTC
# Bitcoin
# Today
# Satoshi Nakaboto
# Bitcoin
# the past 24 hours
# Bentham
# Yolo
# Bitcoin
# the United Nations Childrens Fund
# UNICEF
# UNICEF
# Australias Perth Mint
# one
# today
# Ethereum ETH
# Western Australia
# Hard Fork
# the Perth Mint Gold Token
# first
# Ethereum Foundation's
# Devcon 5
# Osaka
# Japan
# OpenLibra
# Facebook
# OpenLibra
# Libra
# six
# just $2.03 billion
# last quarter
# nearly 40 percent
# 148
# Q3 of this year
# ETH
# Dai
# Good morning Forkers
# Moonday Mornings
# Hard Forks
# 1
# Ukrainian
# Venezuela
# Bloomberg
# four
# Petro
# today
# Ripple XRP Labs
# US
# Fortune
# $24 million
# US
# ICO
# Block.one
# ICO
# Controversial USD
# Tether
# fourth
# Bitcoin
# Ripple
# Tether
# Vodafone
# London
# Apple
# Find Unlimited
# Vatoms
# UK
# around $662,000
# ...
